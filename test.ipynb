# %%
test = {
        "tableau": [
            [
                {
                    "suit": 0,
                    "value": 3
                }
            ],
            [
                {
                    "suit": 1,
                    "value": 5
                }
            ],
            [],
            [],
            [],
            [],
            []
        ]
    }

# %%
from ai import getFree, getMoves

# %%
frees = getFree(test)
print(frees)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 frees = getFree(test)
#       2 print(frees)
#
# File ~/Desktop/solitare/ai.py:9, in getFree(data)
#       7 for col in data["tableau"]:
#       8     if len(col) > 0:
# ----> 9         freeCards.append(Card(col[-1].suit, col[-1].value))
#      10     else:
#      11         freeCards.append(True)
#
# AttributeError: 'dict' object has no attribute 'suit'
